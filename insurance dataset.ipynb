# %%
df=pd.read_csv("C:/Users/Harsha1/Downloads/archive (10)/simplelinearregression.csv")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Age      7 non-null      int64
#  1   Premium  7 non-null      int64
# dtypes: int64(2)
# memory usage: 240.0 bytes

# %%
df.isnull().sum()
# Out:
# Age        0
# Premium    0
# dtype: int64

# %%
plt.scatter(df['Age'],df['Premium'])
plt.xlabel("age")
plt.ylabel("premium")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
df.head(7)
# Out:
#    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000
# 5   31    26500
# 6   33    27000

# %%
X = df[['Age']]
y = df['Premium']
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
print("Coefficient (slope):", model.coef_[0])
print("Intercept:", model.intercept_)
plt.scatter(X, y, label='Actual Data')
plt.plot(X, y_pred, color='red', label='Linear Regression Line')
plt.xlabel('Age')
plt.ylabel('Premium')
plt.legend()
plt.title('Linear Regression: Age vs. Premium')
plt.show()
# Out:
# Coefficient (slope): 1172.9452054794515
# Intercept: -10114.726027397246
